# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from api_keys import weather_api_key

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

from citipy import citipy

# %%
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 568

# %%
# Initialize lists to store data
cities = []
latitudes = []
temperatures = []
humidities = []
cloudiness = []
wind_speeds = []

# Loop through the list of cities and make API requests
for city in city_list:
    # Construct the API URL for each city
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
    
    # Make the API request
    response = requests.get(url).json()
    
    # Check if the city was found in the API response
    if response["cod"] == 200:
        cities.append(city)
        latitudes.append(response["coord"]["lat"])
        temperatures.append(response["main"]["temp"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speeds.append(response["wind"]["speed"])
    else:
        print(f"City not found: {city}")

# Create a DataFrame to store the weather data
weather_data = pd.DataFrame({
    "City": cities,
    "Latitude": latitudes,
    "Temperature (F)": temperatures,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speeds
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7 wind_speeds = []
#       9 # Loop through the list of cities and make API requests
# ---> 10 for city in city_list:
#      11     # Construct the API URL for each city
#      12     url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
#      14     # Make the API request
#
# NameError: name 'city_list' is not defined

# %%
# Initialize lists to store data
cities = []
latitudes = []
temperatures = []
humidities = []
cloudiness = []
wind_speeds = []

# Loop through the list of cities and make API requests
for city in cities:  # Use the correct list name here
    # Construct the API URL for each city
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
    
    # Make the API request
    response = requests.get(url).json()
    
    # Check if the city was found in the API response
    if response["cod"] == 200:
        cities.append(city)
        latitudes.append(response["coord"]["lat"])
        temperatures.append(response["main"]["temp"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speeds.append(response["wind"]["speed"])
    else:
        print(f"City not found: {city}")

# Create a DataFrame to store the weather data
weather_data = pd.DataFrame({
    "City": cities,
    "Latitude": latitudes,
    "Temperature (F)": temperatures,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speeds
})

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}?q={params['q']}&appid={params['appid']}&units={params['units']}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
#   Cell In[10], line 35
#     city_weather = # YOUR CODE HERE
#                    ^
# SyntaxError: invalid syntax

# %%
# Loop through the list of cities and make API requests
for city in cities:
    # Construct the API URL for each city
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": city,
        "appid": weather_api_key,
        "units": "imperial"  # You can adjust units as needed (e.g., "metric" for Celsius)
    }
    
    # Construct the full URL by combining the base URL and parameters
    city_url = f"{base_url}?q={params['q']}&appid={params['appid']}&units={params['units']}"
    
    # Make the API request
    response = requests.get(city_url).json()
    
    # Check if the city was found in the API response
    if response.get("cod") == 200:
        cities.append(city)
        latitudes.append(response["coord"]["lat"])
        temperatures.append(response["main"]["temp"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speeds.append(response["wind"]["speed"])
    else:
        print(f"City not found: {city}")

# Create a DataFrame to store the weather data
weather_data = pd.DataFrame({
    "City": cities,
    "Latitude": latitudes,
    "Temperature (F)": temperatures,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speeds
})

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
#   Cell In[13], line 2
#     city_data_df = # YOUR CODE HERE
#                    ^
# SyntaxError: invalid syntax

# %%
# Create a DataFrame to store the weather data
city_data_df = pd.DataFrame({
    "City": cities,
    "Latitude": latitudes,
    "Temperature (F)": temperatures,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speeds
})

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph)]
# Index: []

# %%
# Loop through the list of cities and make API requests
for city in cities:
    # Construct the API URL for each city
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": city,
        "appid": "1bc56816a6b8fcddbb8f077dde00c9f5",  # Replace with your actual API key
        "units": "imperial"  # You can adjust units as needed (e.g., "metric" for Celsius)
    }
    
    # Construct the full URL by combining the base URL and parameters
    city_url = f"{base_url}?q={params['q']}&appid={params['appid']}&units={params['units']}"
    
    # Make the API request
    response = requests.get(city_url).json()
    
    # Check if the city was found in the API response
    if response.get("cod") == 200:
        cities.append(city)
        latitudes.append(response["coord"]["lat"])
        temperatures.append(response["main"]["temp"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speeds.append(response["wind"]["speed"])
    else:
        print(f"City not found: {city}")

# Create a DataFrame to store the weather data
weather_data = pd.DataFrame({
    "City": cities,
    "Latitude": latitudes,
    "Temperature (F)": temperatures,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": wind_speeds
})

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
params = {
    "q": city,
    "appid": "1bc56816a6b8fcddbb8f077dde00c9f5", 
    "units": "imperial"  
}
city_url = f"{base_url}?q={params['q']}&appid={params['appid']}&units={params['units']}"

# %%
response = requests.get(city_url).json()

# %%
if response.get("cod") == 200:
    cities.append(city)
    latitudes.append(response["coord"]["lat"])
    temperatures.append(response["main"]["temp"])
    humidities.append(response["main"]["humidity"])
    cloudiness.append(response["clouds"]["all"])
    wind_speeds.append(response["wind"]["speed"])
else:
    print(f"City not found: {city}")
# Out:
# City not found: luderitz

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid=1bc56816a6b8fcddbb8f077dde00c9f5"  
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping... ({e})")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(1bc56816a6b8fcddbb8f077dde00c9f5)
# Out:
#   Cell In[24], line 1
#     print(1bc56816a6b8fcddbb8f077dde00c9f5)
#           ^
# SyntaxError: invalid decimal literal

# %%
print("1bc56816a6b8fcddbb8f077dde00c9f5")
# Out:
# 1bc56816a6b8fcddbb8f077dde00c9f5

# %%
# Print the contents of the cities list
print(cities)

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid=1bc56816a6b8fcddbb8f077dde00c9f5"  # Replace with your actual API key
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping... ({e})")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# []
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import requests
import json

api_key = '1bc56816a6b8fcddbb8f077dde00c9f5'

# List of cities
cities = ["faya", "farsund", "new norfolk", "jamestown", "lanzhou", "ushuaia", "albany", "carnarvon", "sisimiut", "samusu", "saint-pierre", "colorado", "nikolskoye", "trairi", "dobryanka", "qaanaaq", "mataura", "khatanga", "tasiilaq", "tiksi", "puerto ayora", "avarua", "nuevo laredo", "guiratinga", "illoqqortoormiut", "taolanaro", "rikitea", "dukat", "constitucion", "nizhneyansk", "senneterre", "bambous virieux", "zangakatun", "saint-louis", "midwest city", "grimmen", "cape town", "stornoway", "naberera", "chokurdakh", "drochia", "klaksvik", "labuhan", "tomatlan", "clyde river", "sao joao da barra", "margate", "ancud", "collierville", "kapaa", "mogadishu", "barentsburg", "tsalka", "dalby", "hobart", "dikson", "hilo", "businga", "khonuu", "lasa", "vaini", "cayenne", "ust-kulom", "udachnyy", "east london", "grand river south east", "busselton", "airai", "grindavik", "barrow", "banda", "atuona", "hermanus", "mar del plata", "caravelas", "port lincoln", "bredasdorp", "mendi", "cobija", "sentyabrskiy", "deer lake", "nalut", "saskylakh", "dudinka", "zamberk", "jaguariaiva", "aberdeen", "mahebourg", "kedrovyy", "makakilo city", "qostanay", "esperance", "darnah", "provideniya", "rafaela", "saint-philippe", "ponta do sol", "solnechnyy", "saint george", "attawapiskat", "alba", "kobojango", "arman", "ugoofaaru", "butaritari", "kavaratti", "zhangye", "shenjiamen", "kamenskoye", "itarema", "trincomalee", "castro", "heihe", "rio gallegos", "siavonga", "bluff", "vaitupu", "nova olimpia", "palencia", "inhambane", "iqaluit", "lebu", "calabozo", "sao filipe", "phan rang", "torbay", "kavieng", "yidu", "kawana waters", "cedar city", "victoria", "ngukurr", "faanui", "arraial do cabo", "hithadhoo", "port alfred", "lichuan", "talnakh", "novorzhev", "muncar", "jashpurnagar", "chuy", "kulykivka", "half moon bay", "bocana de paiwas", "el alto", "sitka", "punta arenas", "bay city", "baruun-urt", "alotau", "ambon", "corowa", "port elizabeth", "ocos", "ge
# Out:
#   Cell In[28], line 7
# ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
import requests
import json

# ...

try:
    # Make the API request
    response = requests.get(1bc56816a6b8fcddbb8f077dde00c9f5)
    # Check if the response status code is 200 (OK)
    if response.status_code == 200:
        # Parse the JSON response
        city_weather = json.loads(response.text)
        # Extract required weather variables
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append data to city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })
    else:
        print("City not found. Skipping...")

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
#   Cell In[3], line 8
#     response = requests.get(1bc56816a6b8fcddbb8f077dde00c9f5)
#                             ^
# SyntaxError: invalid decimal literal

# %%
import requests

# Replace with your OpenWeatherMap API key
api_key = "1bc56816a6b8fcddbb8f077dde00c9f5"

# OpenWeatherMap API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather"

# Specify the location (city name or coordinates)
location = "faya", "farsund", "new norfolk", "jamestown", "lanzhou", "ushuaia", "albany", "carnarvon", "sisimiut", "samusu", "saint-pierre", "colorado", "nikolskoye", "trairi", "dobryanka", "qaanaaq", "mataura", "khatanga", "tasiilaq", "tiksi", "puerto ayora", "avarua", "nuevo laredo", "guiratinga", "illoqqortoormiut", "taolanaro", "rikitea", "dukat", "constitucion", "nizhneyansk", "senneterre", "bambous virieux", "zangakatun", "saint-louis", "midwest city", "grimmen", "cape town", "stornoway", "naberera", "chokurdakh", "drochia", "klaksvik", "labuhan", "tomatlan", "clyde river", "sao joao da barra", "margate", "ancud", "collierville", "kapaa", "mogadishu", "barentsburg", "tsalka", "dalby", "hobart", "dikson", "hilo", "businga", "khonuu", "lasa", "vaini", "cayenne", "ust-kulom", "udachnyy", "east london", "grand river south east", "busselton", "airai", "grindavik", "barrow", "banda", "atuona", "hermanus", "mar del plata", "caravelas", "port lincoln", "bredasdorp", "mendi", "cobija", "sentyabrskiy", "deer lake", "nalut", "saskylakh", "dudinka", "zamberk", "jaguariaiva", "aberdeen", "mahebourg", "kedrovyy", "makakilo city", "qostanay", "esperance", "darnah", "provideniya", "rafaela", "saint-philippe", "ponta do sol", "solnechnyy", "saint george", "attawapiskat", "alba", "kobojango", "arman", "ugoofaaru", "butaritari", "kavaratti", "zhangye", "shenjiamen", "kamenskoye", "itarema", "trincomalee", "castro", "heihe", "rio gallegos", "siavonga", "bluff", "vaitupu", "nova olimpia", "palencia", "inhambane", "iqaluit", "lebu", "calabozo", "sao filipe", "phan rang", "torbay", "kavieng", "yidu", "kawana waters", "cedar city", "victoria", "ngukurr", "faanui", "arraial do cabo", "hithadhoo", "port alfred", "lichuan", "talnakh", "novorzhev", "muncar", "jashpurnagar", "chuy", "kulykivka", "half moon bay", "bocana de paiwas", "el alto", "sitka", "punta arenas", "bay city", "baruun-urt", "alotau", "ambon", "corowa", "port elizabeth", "ocos"

# Create the request URL with parameters
params = {
    "q": location,
    "appid": api_key,
    "units": "metric"  # You can choose Celsius or Fahrenheit for units
}

# Make the GET request
response = requests.get(base_url, params=params)

if response.status_code == 200:
    # The request was successful, and you can access the weather data with response.json()
    data = response.json()
    print("Weather in {}: {}".format(location, data['weather'][0]['description']))
else:
    # Handle errors here
    print("Request failed with status code:", response.status_code)
# Out:
# Weather in ('faya', 'farsund', 'new norfolk', 'jamestown', 'lanzhou', 'ushuaia', 'albany', 'carnarvon', 'sisimiut', 'samusu', 'saint-pierre', 'colorado', 'nikolskoye', 'trairi', 'dobryanka', 'qaanaaq', 'mataura', 'khatanga', 'tasiilaq', 'tiksi', 'puerto ayora', 'avarua', 'nuevo laredo', 'guiratinga', 'illoqqortoormiut', 'taolanaro', 'rikitea', 'dukat', 'constitucion', 'nizhneyansk', 'senneterre', 'bambous virieux', 'zangakatun', 'saint-louis', 'midwest city', 'grimmen', 'cape town', 'stornoway', 'naberera', 'chokurdakh', 'drochia', 'klaksvik', 'labuhan', 'tomatlan', 'clyde river', 'sao joao da barra', 'margate', 'ancud', 'collierville', 'kapaa', 'mogadishu', 'barentsburg', 'tsalka', 'dalby', 'hobart', 'dikson', 'hilo', 'businga', 'khonuu', 'lasa', 'vaini', 'cayenne', 'ust-kulom', 'udachnyy', 'east london', 'grand river south east', 'busselton', 'airai', 'grindavik', 'barrow', 'banda', 'atuona', 'hermanus', 'mar del plata', 'caravelas', 'port lincoln', 'bredasdorp', 'mendi', 'cobija',
# ...

# %%
# Print the contents of the cities list
print()

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid=1bc56816a6b8fcddbb8f077dde00c9f5"  # Replace with your actual API key
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping... ({e})")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Print the contents of the cities list
# ----> 2 print(cities)
#       4 # Loop through all the cities in our list to fetch weather data
#       5 for i, city in enumerate(cities):
#       6     # Create endpoint URL with each city
#
# NameError: name 'cities' is not defined

# %%
import requests

# Replace with your OpenWeatherMap API key
api_key = "1bc56816a6b8fcddbb8f077dde00c9f5"

# OpenWeatherMap API base URL for current weather data
base_url = "https://api.openweathermap.org/data/2.5/weather"

# Define a list of cities you want to fetch weather data for
cities = ["faya", "farsund", "new norfolk", "jamestown", "lanzhou", "ushuaia", "albany", "carnarvon", "sisimiut", "samusu", "saint-pierre", "colorado", "nikolskoye", "trairi", "dobryanka", "qaanaaq", "mataura", "khatanga", "tasiilaq", "tiksi", "puerto ayora", "avarua", "nuevo laredo", "guiratinga", "illoqqortoormiut", "taolanaro", "rikitea", "dukat", "constitucion", "nizhneyansk", "senneterre", "bambous virieux", "zangakatun", "saint-louis", "midwest city", "grimmen", "cape town", "stornoway", "naberera", "chokurdakh", "drochia", "klaksvik", "labuhan", "tomatlan", "clyde river", "sao joao da barra", "margate", "ancud", "collierville", "kapaa", "mogadishu", "barentsburg", "tsalka", "dalby", "hobart", "dikson", "hilo", "businga", "khonuu", "lasa", "vaini", "cayenne", "ust-kulom", "udachnyy", "east london", "grand river south east", "busselton", "airai", "grindavik", "barrow", "banda", "atuona", "hermanus", "mar del plata", "caravelas", "port lincoln", "bredasdorp", "mendi", "cobija", "sentyabrskiy", "deer lake", "nalut", "saskylakh", "dudinka", "zamberk", "jaguariaiva", "aberdeen", "mahebourg", "kedrovyy", "makakilo city", "qostanay", "esperance", "darnah", "provideniya", "rafaela", "saint-philippe", "ponta do sol", "solnechnyy", "saint george", "attawapiskat", "alba", "kobojango", "arman", "ugoofaaru", "butaritari", "kavaratti", "zhangye", "shenjiamen", "kamenskoye", "itarema", "trincomalee", "castro", "heihe", "rio gallegos", "siavonga", "bluff", "vaitupu", "nova olimpia", "palencia", "inhambane", "iqaluit", "lebu", "calabozo", "sao filipe", "phan rang", "torbay", "kavieng", "yidu", "kawana waters", "cedar city", "victoria", "ngukurr", "faanui", "arraial do cabo", "hithadhoo", "port alfred", "lichuan", "talnakh", "novorzhev", "muncar", "jashpurnagar", "chuy", "kulykivka", "half moon bay", "bocana de paiwas", "el alto", "sitka", "punta arenas", "bay city", "baruun-urt", "alotau", "ambon", "corowa", "port elizabeth", "ocos"
]

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Create endpoint URL with each city
    params = {
        "q": city,
        "appid": api_key,
        "units": "metric"  # You can choose Celsius or Fahrenheit for units
    }
    
    # Make the GET request for weather data
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        # The request was successful, and you can access the weather data with response.json()
        data = response.json()
        print(f"Weather in {city}: {data['weather'][0]['description']}")
    else:
        # Handle errors here
        print(f"Request for {city} failed with status code: {response.status_code}")
# Out:
# Weather in faya: broken clouds
# Weather in farsund: overcast clouds
# Weather in new norfolk: light rain
# Weather in jamestown: overcast clouds
# Weather in lanzhou: overcast clouds
# Weather in ushuaia: clear sky
# Weather in albany: overcast clouds
# Weather in carnarvon: clear sky
# Weather in sisimiut: few clouds
# Request for samusu failed with status code: 404
# Weather in saint-pierre: clear sky
# Weather in colorado: scattered clouds
# Weather in nikolskoye: clear sky
# Weather in trairi: overcast clouds
# Weather in dobryanka: few clouds
# Weather in qaanaaq: overcast clouds
# Weather in mataura: overcast clouds
# Weather in khatanga: overcast clouds
# Weather in tasiilaq: clear sky
# Weather in tiksi: few clouds
# Weather in puerto ayora: broken clouds
# Weather in avarua: light rain
# Weather in nuevo laredo: clear sky
# Weather in guiratinga: overcast clouds
# Request for illoqqortoormiut failed with status code: 404
# Request for taolanaro failed with status code: 404
# ...

# %%
# Set the API base URL
url = https://api.openweathermap.org/data/2.5/weather

city_data = ["faya", "farsund", "new norfolk", "jamestown", "lanzhou", "ushuaia", "albany", "carnarvon", "sisimiut", "samusu", "saint-pierre", "colorado", "nikolskoye", "trairi", "dobryanka", "qaanaaq", "mataura", "khatanga", "tasiilaq", "tiksi", "puerto ayora", "avarua", "nuevo laredo", "guiratinga", "illoqqortoormiut", "taolanaro", "rikitea", "dukat", "constitucion", "nizhneyansk", "senneterre", "bambous virieux", "zangakatun", "saint-louis", "midwest city", "grimmen", "cape town", "stornoway", "naberera", "chokurdakh", "drochia", "klaksvik", "labuhan", "tomatlan", "clyde river", "sao joao da barra", "margate", "ancud", "collierville", "kapaa", "mogadishu", "barentsburg", "tsalka", "dalby", "hobart", "dikson", "hilo", "businga", "khonuu", "lasa", "vaini", "cayenne", "ust-kulom", "udachnyy", "east london", "grand river south east", "busselton", "airai", "grindavik", "barrow", "banda", "atuona", "hermanus", "mar del plata", "caravelas", "port lincoln", "bredasdorp", "mendi", "cobija", "sentyabrskiy", "deer lake", "nalut", "saskylakh", "dudinka", "zamberk", "jaguariaiva", "aberdeen", "mahebourg", "kedrovyy", "makakilo city", "qostanay", "esperance", "darnah", "provideniya", "rafaela", "saint-philippe", "ponta do sol", "solnechnyy", "saint george", "attawapiskat", "alba", "kobojango", "arman", "ugoofaaru", "butaritari", "kavaratti", "zhangye", "shenjiamen", "kamenskoye", "itarema", "trincomalee", "castro", "heihe", "rio gallegos", "siavonga", "bluff", "vaitupu", "nova olimpia", "palencia", "inhambane", "iqaluit", "lebu", "calabozo", "sao filipe", "phan rang", "torbay", "kavieng", "yidu", "kawana waters", "cedar city", "victoria", "ngukurr", "faanui", "arraial do cabo", "hithadhoo", "port alfred", "lichuan", "talnakh", "novorzhev", "muncar", "jashpurnagar", "chuy", "kulykivka", "half moon bay", "bocana de paiwas", "el alto", "sitka", "punta arenas", "bay city", "baruun-urt", "alotau", "ambon", "corowa", "port elizabeth", "ocos"
]

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = "https://api.openweathermap.org/data/2.5/weather"



    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
#   Cell In[16], line 2
#     url = https://api.openweathermap.org/data/2.5/weather
#                ^
# SyntaxError: invalid syntax
